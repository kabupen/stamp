# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.animation as animation
# Out:
# Traceback (most recent call last):
#   File "/Users/takeda/.pyenv/versions/3.7.3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py", line 196, in process
#     func(*args, **kwargs)
#   File "/Users/takeda/.pyenv/versions/3.7.3/lib/python3.7/site-packages/matplotlib/animation.py", line 1467, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'

# %%
# %matplotlib nbagg
np.random.seed(123)
x = np.random.randn(100)

absmax_x = np.ceil(np.max(np.abs(x)))
xmin, xmax = -absmax_x, absmax_x

def animate(nframe):
    plt.cla()
    plt.hist(x[:nframe], bins=20)
    plt.xlim(xmin , xmax)
    plt.ylim(0, 50)
    
fig = plt.figure()
anim = animation.FuncAnimation(fig, animate, np.arange(1, 100+1))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.8749935645611">
